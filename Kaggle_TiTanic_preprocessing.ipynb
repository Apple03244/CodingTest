# %% [markdown]
# <a href="https://colab.research.google.com/github/Apple03244/CodingTest/blob/main/Kaggle_TiTanic_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.colab as colab
f=colab.files.upload()
# Out:
#      <input type="file" id="files-ec0d2df2-b20d-4e01-afde-e5c5d505c81f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec0d2df2-b20d-4e01-afde-e5c5d505c81f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning 방지
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c titanic
# Out:
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 32.9MB/s]

# %%
# zip 파일로 다운받아졌으므로
! unzip /content/titanic.zip
# Out:
# Archive:  /content/titanic.zip
#   inflating: gender_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
train=pd.read_csv('/content/train.csv')
test=pd.read_csv('/content/test.csv')
sub_mission=pd.read_csv('/content/gender_submission.csv')

# %%
import sklearn.preprocessing as skpre
import sklearn.model_selection as skmod
import sklearn.impute as skimp
import sklearn.compose as skcom
import sklearn.pipeline as skpip
import sklearn.multioutput as skmult

# %%
# 승객번호는 나에게 필요없다
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# ## preprocessing
# - 1. Nan values

# %%
target_col=["Survived"]
numeric_cols=["Age","SibSp","Parch","Fare"]
cate_cols=["Pclass","Sex","Embarked"]

# %%
import numpy as np

# %% [markdown]
# 1. use MultiRegressior to predict Nan values
#
# We need to consider what is best estimator for

# %%
import sklearn.ensemble as skens
estimator=skens.RandomForestRegressor(n_estimators=100
                                      ,criterion="squared_error",
                                      random_state=10,n_jobs=3)
multigressior=skmult.MultiOutputRegressor(estimator=estimator,n_jobs=-1)

# %%
predict_nan_model=skpip.make_pipeline(skpre.MinMaxScaler(),
                                      multigressior)

# %%
numeric_train=train[numeric_cols].dropna(axis=0)

# %%
numeric_train
# Out:
#       Age  SibSp  Parch     Fare
# 0    22.0      1      0   7.2500
# 1    38.0      1      0  71.2833
# 2    26.0      0      0   7.9250
# 3    35.0      1      0  53.1000
# 4    35.0      0      0   8.0500
# ..    ...    ...    ...      ...
# 885  39.0      0      5  29.1250
# 886  27.0      0      0  13.0000
# 887  19.0      0      0  30.0000
# 889  26.0      0      0  30.0000
# 890  32.0      0      0   7.7500
#
# [714 rows x 4 columns]

# %% [markdown]
# 모델 평가 해야됌~
# 이거 안되면 estimator 바꾸고,
# 그것도 안되면 케라스 이용해야함
